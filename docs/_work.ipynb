# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import sys

repo_root = Path.cwd().parent  # docs/ -> repo root
sys.path.insert(0, str(repo_root))
# import tests.fixtures.test_case_catalog as cases
import tests.fixtures.test_case_catalog as cases
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # single sim test case

# %%
case = cases.Local_cases.retrieve_norfolk_single_sim_test_case(
        start_from_scratch=False, download_if_exists=False
    )

# %%
case.system.cfg_system.display_tabulate_cfg()
# Out:
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | attr_name                 | desc                                                         | val                                                          |
# +===========================+==============================================================+==============================================================+
# | system_directory          | Path where TRITON-SWMM system outputs will be stored.        | /home/***REMOVED***/dev/TRITON-                                     |
# |                           |                                                              | SWMM_toolkit/test_data/norfolk_coastal_flooding/tests        |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | watershed_gis_polygon     | Watershed or subcatchment gis used for plotting.             | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           |                                                              | lk_coastal_flooding/data/contents/shp_watershed/norfolk_wshe |
# |                           |                                                              | d_epsg32147_state_plane_m.shp                                |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | DEM_fullres               | DEM to be formatted and, if desired, coarsened, for TRITON   | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           |                                                              | lk_coastal_flooding/data/contents/fullres_dem_m.tif          |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_lookup_file       | CSV file containing lookup table relating landuse categories | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           | to manning's roughness coefficients                          | lk_coastal_flooding/data/contents/landuse_lookup_tables.csv  |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | SWMM_hydraulics           | Hydraulics-only SWMM model (.inp) template with fillable     | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           | fields based on input weather data. An event-specific        | lk_coastal_flooding/data/contents/swmm/hague_hydraulics_mode |
# |                           | scenario of this model will be input to TRITON-SWMM.         | l_template.inp                                               |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | SWMM_hydrology            | Hydrology-only SWMM model (.inp) template with fillable      | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           | fields based on input weather data. This will be run prior   | lk_coastal_flooding/data/contents/swmm/hague_hydrology_model |
# |                           | to TRITON-SWMM to generate runoff time series in grid cells  | _template.inp                                                |
# |                           | that overlap with subcatchment outlet nodes.                 |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | SWMM_full                 | Full SWMM model (.inp) template with fillable fields based   | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           | on input weather data. Scenarios based on this can be run in | lk_coastal_flooding/data/contents/swmm/hague_full_model_temp |
# |                           | addition to TRITON-SWMM to compare SWMM hydraulics results.  | late.inp                                                     |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_raster            | Landuse raster used for creating manning's roughness input.  | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# |                           |                                                              | lk_coastal_flooding/data/contents/landuse_clipped_to_triton_ |
# |                           |                                                              | extent.tif                                                   |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | TRITONSWMM_software_direc | Folder containing the TRITONSWMM model software.             | /home/***REMOVED***/dev/TRITON-                                     |
# | tory                      |                                                              | SWMM_toolkit/test_data/norfolk_coastal_flooding/triton       |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | TRITONSWMM_git_URL        | Git repository with TRITONSWMM                               | https://code.ornl.gov/hydro/triton.git                       |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | TRITONSWMM_branch_key     | TRITONSWMM branch to checkout. Known working branches:       | 1642a7d47b1460253c9ad7626004453c633ce846                     |
# |                           | 02438b60613a7d913d884e7b836f9f5ff421fe7d                     |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | gpu_compilation_backend   | GPU backend for compilation: 'HIP' for AMD GPUs (ROCm),      | None                                                         |
# |                           | 'CUDA' for NVIDIA GPUs. If None, only CPU (OPENMP) backend   |                                                              |
# |                           | will be compiled. When set, both CPU and GPU backends are    |                                                              |
# |                           | compiled into separate build directories.                    |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | additional_modules_needed | Space separated list of modules to load using 'module load'  | None                                                         |
# | _to_run_TRITON_SWMM_on_hp | prior to running each TRITON-SWMM simulatoin, e.g,. 'PrgEnv- |                                                              |
# | c                         | amd Core/24.07 craype-accel-amd-gfx90a'                      |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | subcatchment_raingage_map | Lookup table relating spatially indexed rainfall time series | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# | ping                      | to SWMM subcatchment IDs.                                    | lk_coastal_flooding/data/contents/b_sub_ids_and_mrms_rain_co |
# |                           |                                                              | l.csv                                                        |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | triton_swmm_configuration | Path to the template TRITON-SWMM cfg file that defines the   | /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfo |
# | _template                 | variables and inputs per simulation.                         | lk_coastal_flooding/data/contents/TRITON_SWMM_definition_tem |
# |                           |                                                              | plate.cfg                                                    |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_description_colna | column name in the landuse_lookup_file corresponding to      | original_description                                         |
# | me                        | landuse description.                                         |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_lookup_class_id_c | column name in the landuse_lookup_file corresponding to      | CLASS_ID                                                     |
# | olname                    | landuse classification.                                      |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_lookup_mannings_c | column name in the landuse_lookup_file corresponding to      | mannings                                                     |
# | olname                    | manning's coefficient.                                       |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | landuse_plot_color_colnam | column name in the landuse_lookup_file corresponding to      | plot_color                                                   |
# | e                         | target plot colors by landuse.                               |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | subcatchment_raingage_map | Column name in subcatchment_raingage_mapping_gage            | raingage_id                                                  |
# | ping_gage_id_colname      | corresponding to the rain gage ids.                          |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | dem_outside_watershed_hei | DEM height applied to grid cells outside of the watershed    | 9999.0                                                       |
# | ght                       | boundary. Used for scaling DEM plot colorbars.               |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | dem_building_height       | DEM height applied to DEM gridcells overlapping buildings.   | 80.0                                                         |
# |                           | Used for scaling DEM plot colorbars.                         |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | toggle_use_swmm_for_hydro | Determines whether a hydrology-only SWMM model will be used  | true                                                         |
# | logy                      | for rainfall-runoff calculations.                            |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | toggle_use_constant_manni | Determines whether or not to use a constant manning's        | false                                                        |
# | ngs                       | coefficient.                                                 |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | toggle_full_swmm_model    | Determines whether or not a basic SWMM model will be run     | true                                                         |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | target_dem_resolution     | Target DEM resolution for TRITON-SWMM in the native          | 3.5                                                          |
# |                           | resolution of the provided DEM.                              |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+
# | constant_mannings         | Constant manning's coefficient to use. Only applies if       | None                                                         |
# |                           | toggle_use_constant_mannings is set to True.                 |                                                              |
# +---------------------------+--------------------------------------------------------------+--------------------------------------------------------------+

# %%
case.analysis.cfg_analysis.print_files_defined_in_yaml()
# Out:
# /home/***REMOVED***/
# ├── dev/
# │   └── TRITON-SWMM_toolkit/
# │       └── test_data/
# │           └── norfolk_coastal_flooding/
# │               └── tests/
# │                   └── single_sim/
# │                       ├── weather_tseries.nc
# │                       └── weather_indices.csv
# └── .local/
#     └── share/
#         └── TRITON_SWMM_toolkit/
#             └── examples/
#                 └── norfolk_coastal_flooding/
#                     └── data/
#                         └── contents/
#                             └── shp_boundary_condition/
#                                 └── variable_bc.shp

# %%
case.system.process_system_level_inputs()

# %%
case.system.compile_TRITON_SWMM(redownload_triton_swmm_if_exists=False, recompile_if_already_done_successfully=False)
# Out:
# [CMAKE PATCH] cmake/machine.cmake already patched (skipping)
#
# ============================================================
# Compiling CPU Backend
# ============================================================
# [CPU] Starting compilation...
# [CPU]   Script: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/compile_cpu.sh
# [CPU] ✓ Compilation successful!
#
# ============================================================
# Compilation Status
# ============================================================
# ✓ CPU backend: COMPILED SUCCESSFULLY
#   Build: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/triton/build_cpu
#   GPU backend: NOT REQUESTED
#
# Available backends: cpu
# ============================================================

# %%
case.analysis.run_prepare_scenarios_serially(
        overwrite_scenarios=True, rerun_swmm_hydro_if_outputs_exist=True
    )
# Out:
# 2026-01-30 16:18:18,332 [INFO] Loading system configuration from /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/tests.yaml
# 2026-01-30 16:18:18,335 [INFO] Loading analysis configuration from /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/single_sim/single_sim.yaml
# 2026-01-30 16:18:18,341 [INFO] Preparing scenario 0
# [Scenario 0] Using CPU backend
#
# ... SWMM Version 5.2.4
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... Run CompleteScenario preparation complete
# 2026-01-30 16:18:21,566 [INFO] Scenario 0 prepared successfully

# %%
case.analysis.run_sims_in_sequence(pickup_where_leftoff=False)

# %%
case.analysis.process_all_sim_timeseries_serially()
# Out:
# Processing run results for scenario 0
# Processed TRITON outputs for scenario 0
# ##################################
# Found problem. Orifice conduits do not return max velocity or max over full flow. Filling with empty string
# Normal row vs. problem row:
#   0                    CONDUIT     0.000     0  00:01      0.00    0.00    0.00
#
#   756                  ORIFICE     0.000     0  00:00                      0.00
#
# Properly parsed values:
# ['756', 'ORIFICE', '0.000', '0', '00:00', '', '', '0.00\n']
# Converted variable to datatype = type, <class 'str'>
# Converted variable to datatype = type, <class 'str'>
# Processed SWMM outputs for scenario 0

# %% [markdown]
# # multi-sim case

# %%
case = cases.Local_TestCases.retrieve_norfolk_multi_sim_test_case(start_from_scratch=False)
analysis = case.analysis

# %%
# analysis = norfolk_multi_sim_analysis

result = analysis.submit_workflow(
    mode="local",
    process_system_level_inputs=True,
    overwrite_system_inputs=True,
    compile_TRITON_SWMM=True,
    recompile_if_already_done_successfully=True,
    prepare_scenarios=True,
    overwrite_scenario=True,
    rerun_swmm_hydro_if_outputs_exist=True,
    process_timeseries=True,
    which="both",
    clear_raw_outputs=True,
    overwrite_if_exist=True,
    compression_level=5,
    pickup_where_leftoff=False,
    dry_run=False,
    verbose=True,
)
# Out:
# [Snakemake] Submitting workflow in local mode
# [Snakemake] Snakefile generated: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/Snakefile
# [Snakemake] Running workflow locally with Snakemake
# [Snakemake] DRY RUN
# [Snakemake] Using dynamic config from: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/.snakemake_profile/local
# [Snakemake] Workflow completed successfully
# [Snakemake] Running workflow locally with Snakemake
# [Snakemake] Using dynamic config from: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/.snakemake_profile/local
# [Snakemake] Workflow completed successfully

# %%
analysis.SWMM_node_summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 analysis.SWMM_node_summary
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/analysis.py:1121, in TRITONSWMM_analysis.SWMM_node_summary(self)
#    1119 @property
#    1120 def SWMM_node_summary(self):
# -> 1121     return self.process.SWMM_node_summary
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/processing_analysis.py:194, in TRITONSWMM_analysis_post_processing.SWMM_node_summary(self)
#     192 @property
#     193 def SWMM_node_summary(self):
# --> 194     return self._open(self._analysis.analysis_paths.output_swmm_node_summary)
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/processing_analysis.py:188, in TRITONSWMM_analysis_post_processing._open(self, f)
#     184     return xr.open_dataset(
#     185         f, chunks="auto", engine=self._open_engine(), consolidated=False  # type: ignore
#     186     )
#     187 else:
# --> 188     raise ValueError(
#     189         f"could not open file because it does not exist: {f}. Run analysis.consolidate_[SWMM/TRITON]_outputs()."
#     190     )
#
# ValueError: could not open file because it does not exist: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/SWMM_nodes.zarr. Run analysis.consolidate_[SWMM/TRITON]_outputs().

# %% [markdown]
# # sensitivity analysis

# %%
nrflk_cpu_sensitivity = cases.Local_TestCases.retrieve_norfolk_cpu_config_sensitivity_case(
        start_from_scratch=True
    )
analysis = nrflk_cpu_sensitivity.analysis

# %%
result = analysis.submit_workflow(
    mode="local",
    process_system_level_inputs=True,
    overwrite_system_inputs=True,
    compile_TRITON_SWMM=True,
    recompile_if_already_done_successfully=True,
    prepare_scenarios=True,
    overwrite_scenario=True,
    rerun_swmm_hydro_if_outputs_exist=True,
    process_timeseries=True,
    which="both",
    clear_raw_outputs=True,
    overwrite_if_exist=True,
    compression_level=5,
    pickup_where_leftoff=False,
    dry_run=True,
    verbose=True,
)
# Out:
# [Snakemake] Submitting sensitivity analysis workflow in local mode
# [Snakemake] Generated master Snakefile: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/cpu_config_sensitivity/Snakefile
# [Snakemake] Created required directories (_status, logs/sims)
# [Snakemake] Running workflow locally with Snakemake
# [Snakemake] Using dynamic config from: /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/cpu_config_sensitivity/.snakemake_profile/local
# [Snakemake] Workflow completed successfully

# %%
case = cases.Local_TestCases.retrieve_norfolk_cpu_config_sensitivity_case(start_from_scratch=False)
analysis = case.analysis

# %%
analysis.sensitivity.compile_TRITON_SWMM_for_sensitivity_analysis()
assert analysis.sensitivity.compilation_successful == True

# %%
analysis.sensitivity.prepare_scenarios_in_each_subanalysis(concurrent=True)
assert analysis.log.all_scenarios_created.get() == True

# %%
analysis.sensitivity.run_all_sims(pickup_where_leftoff=False, concurrent=False)
# assert analysis.log.all_sims_run.get() == True
