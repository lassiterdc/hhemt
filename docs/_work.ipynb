# %%
# %load_ext autoreload
# %autoreload 2
import TRITON_SWMM_toolkit.examples as examples
import TRITON_SWMM_toolkit.analysis as analysis
from TRITON_SWMM_toolkit.process_simulation import TRITONSWMM_sim_post_processing
import TRITON_SWMM_toolkit.process_simulation as ps
import TRITON_SWMM_toolkit.processing_analysis as pe
from TRITON_SWMM_toolkit.process_simulation import *
import TRITON_SWMM_toolkit.plot_utils as plot_utils
import TRITON_SWMM_toolkit.utils as utils 
import TRITON_SWMM_toolkit.run_simulation as run
import TRITON_SWMM_toolkit.sensitivity_analysis as snst
from TRITON_SWMM_toolkit.config import analysis_config
from TRITON_SWMM_toolkit.examples import GetTS_TestCases as tst
from importlib import reload
reload(examples)
reload(analysis)
reload(ps)
reload(pe)
reload(plot_utils)
reload(utils)
reload(snst)
# norfolk_singlesim = examples.GetTS_TestCases.retreive_norfolk_single_sim_test_case(download_if_exists=False)
# norfolk_multisim = examples.GetTS_TestCases.retreive_norfolk_multi_sim_test_case()

rebuild_case = True
nrflk_multisim_ensemble = tst.retreive_norfolk_multi_sim_test_case(start_from_scratch=rebuild_case)
self = nrflk_multisim_ensemble.system.analysis
nrflk_multisim_ensemble.system.process_system_level_inputs(overwrite_if_exists=rebuild_case)
self.compile_TRITON_SWMM(recompile_if_already_done_successfully=rebuild_case)
# self.sensitivity.prepare_scenarios_in_each_subanalysis()
# self.prepare_all_scenarios()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# swig/python detected a memory leak of type 'struct Handle *', no destructor found.

# %%
launcher_logfile = self.scenarios[0].log.logfile.parent / "scenario_prep.log"
prepare_scenario_launchers = self.retrieve_prepare_scenario_launchers(
    overwrite_scenario=True, verbose=True
)
log_path = prepare_scenario_launchers[0]()
print(f"Log file written to {log_path}")
# Out:
# ... SWMM Version 5.2.4
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... Run Complete
# PosixPath('/home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/sims/0-event_id.0/scenario_prep.log')

# %%
self.run_python_functions_concurrently(prepare_scenario_launchers)
scens_not_created = "\n".join(self.scenarios_not_created)
print(scens_not_created)
# self.scenarios_not_created
# Out:
# Memory-based limit: 2 (available 2441 MiB, 1024 MiB per task)
# Running 2 functions (max parallel = 1)
#
# ... SWMM Version 5.2.4
# ... Run Complete
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete           Function 0 completed in 3.61 s
#
# ... SWMM Version 5.2.4
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... Run CompleteFunction 1 completed in 2.86 s

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prepare_scenario_launchers[0]()
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/log.py:558, in log_function_to_file.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     554 logger.addHandler(fh)
#     556 try:
#     557     # Call the wrapped function, passing the logger in
# --> 558     return func(*args, logger=logger, **kwargs)
#     559 except Exception:
#     560     logger.exception("Exception occurred during function execution")
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/scenario.py:858, in TRITONSWMM_scenario.prepare_scenario.<locals>.launcher(overwrite_scenario, rerun_swmm_hydro_if_outputs_exist, verbose, logger)
#     855     self.log.inp_hydro_model_created_successfully.set(True)
#     857 self._create_external_boundary_condition_files()
# --> 858 self._write_hydrograph_files()
#     859 self._update_hydraulics_model_to_have_1_inflow_node_per_DEM_gridcell(
#     860     verbose=False
#     861 )
#     862 self._generate_TRITON_SWMM_cfg()
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/scenario.py:448, in TRITONSWMM_scenario._write_hydrograph_files(self)
#     446 d_time_series = dict()
#     447 lst_nodes_with_inflow = []
# --> 448 with Output(hydro_outfile) as out:
#     449     flow_units = out.units["flow"]  # type: ignore
#     450     inflow_first_line = f"%Runoff for sim {sim_id_str}\n"
#
# File ~/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/pyswmm/output.py:205, in Output.__enter__(self)
#     204 def __enter__(self):
# --> 205     self.open()
#     206     return self
#
# File ~/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/pyswmm/output.py:180, in Output.open(self)
#     178 if not self.loaded:
#     179     self.loaded = True
# --> 180     output.open(self.handle, self.binfile)
#     181     self.start = from_jd(output.get_start_date(self.handle) + 2415018.5)
#     182     self.start = self.start.replace(microsecond=0)
#
# File ~/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/swmm/toolkit/output.py:105, in open(p_handle, path)
#      93 def open(p_handle, path):
#      94     r"""
#      95     Open binary output file and reads prologue and epilogue.
#      96
#    (...)    103
#     104     """
# --> 105     return _output.open(p_handle, path)
#
# Exception: ERROR 440: an unspecified error has occurred

# %% [markdown]
# # debugging sensitivity analysis stuff

# %%
nrflk_cpu_sensitivity = tst.retreive_norfolk_cpu_config_sensitivity_case(
    start_from_scratch=True
)
analysis = nrflk_cpu_sensitivity.system.analysis
analysis.compile_TRITON_SWMM(recompile_if_already_done_successfully=True)
assert analysis.compilation_successful == True
# prepare scenarios
analysis.sensitivity.prepare_scenarios_in_each_subanalysis(concurrent=True)
assert analysis.log.all_scenarios_created.get() == True
# run sims
analysis.sensitivity.run_all_sims(pickup_where_leftoff=False, concurrent=True)
assert analysis.log.all_sims_run.get() == True
# Out:
# ... SWMM Version 5.2.4
# ... Run Complete
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... SWMM Version 5.2.4
#  o  Retrieving project data
# ... Run Complete
#  o  Simulating day: 0     hour: Simulation complete
# ... SWMM Version 5.2.4
#  o  Retrieving project data
# ... Run Complete
#  o  Simulating day: 0     hour: Simulation complete
# ... SWMM Version 5.2.4
#  o  Retrieving project data
# ... Run Complete
#  o  Simulating day: 0     hour: Simulation complete

# %%
# consolidate outputs
analysis.sensitivity.process_simulation_timeseries_concurrently(
        overwrite_if_exist=True
    )

# %%
# running multiple sims concurrently
launch_functions = self._create_launchable_sims()
self.run_simulations_concurrently_on_desktop(launch_functions=launch_functions, verbose = True)
# Out:
# Running up to 4 simulations concurrently
# Simulation finished: simulation completed
# Simulation finished: simulation completed
# ['simulation completed', 'simulation completed']

# %%
self.run_simulations_concurrently_on_SLURM_HPC(launch_functions)

# %%
# running single sim 
self.run_sim(0, pickup_where_leftoff=False, process_outputs_after_sim_completion = False, which = "both", clear_raw_outputs=False, overwrite_if_exist=False, compression_level=5, verbose = True)
# Out:
# run instance instantiated
# running TRITON-SWMM simulatoin for event 0-event_id.0
# bash command to view progress:
# tail -f /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/2026-01-14T105454-0500.log

# %%
# Out:
# running TRITON-SWMM simulatoin for event 0-event_id.0
# bash command to view progress:
# tail -f /home/***REMOVED***/dev/TRITON-SWMM_toolkit/test_data/norfolk_coastal_flooding/tests/multi_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/2026-01-14T104700-0500.log

# %%
elapsed
# Out:
# 8.297805070877075

# %%
from TRITON_SWMM_toolkit import examples

examples.load_norfolk_system_config(download_if_exists=True)
# Out:
# signed into Hydroshare successfully.
# Retrieving /hsapi/resource/a4aace329b8c401a93e94ce2a761fe1b
# PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/system/config_system.yaml')

# %%
run_command = self.retrieve_sim_command_text(in_slurm = True)
self.create_ensemble_bash_script(run_command)

print(utils.read_text_file_as_string(self.analysis_paths.bash_script_path))
# Out:
# #!/bin/bash
# #SBATCH -o _slurm_outputs/%x/%A_outputs_%a_%N.out
# #SBATCH -e _slurm_outputs/%x/%A_errors_%a_%N.out
# #SBATCH -A ***REMOVED***
# #SBATCH -t 02:00:00
# #SBATCH -p batch
# #SBATCH -N 1
# #SBATCH --exclusive
# # SBATCH --cpus-per-task=${cpus_per_task}   # CPU=1, GPU=threads per GPU
# # SBATCH --ntasks-per-node=${ntasks_per_node} # GPU=tasks per node, CPU optional
# # SBATCH --gres=None
# #SBATCH --mail-user=***REMOVED***@virginia.edu
# #SBATCH --mail-type=ALL
# #SBATCH -q debug
#
# set -euo pipefail
#
# # Load modules
# module purge
# module load PrgEnv-amd Core/24.07 cmake/3.27.9 craype-accel-amd-gfx90a
# module load miniforge3/23.11.0
# DIR=~/.conda/envs/running_swmm
#
# echo "Node CPUs: $(nproc)"
# echo "SLURM_CPUS_ON_NODE=${SLURM_CPUS_ON_NODE:-unset}"
#
# export ROCM_PATH=${CRAY_AMD_COMPILER_PREFIX}
# export CXX=CC
# export MPICH_GPU_SUPPORT_ENABLED=1
# export TRITON_BACKEND="Kokkos_ENABLE_HIP"
# export TRITON_ARCH="Kokkos_ARCH_AMD_GFX90A"
# export TRITON_CXX_FLAGS="-DTRITON_HIP_LAUNCHER;-O3;-ffast-math;-I${ROCM_PATH}/include;-D__HIP_ROCclr__;-D__HIP_ARCH_GFX90A__=1;--rocm-path=${ROCM_PATH};--offload-arch=gfx90a;-Wno-unused-result;-Wno-macro-re
# defined"
# export TRITON_LINK_FLAGS="--rocm-path=${ROCM_PATH};-L${ROCM_PATH}/lib;-lamdhip64"
# export TRITON_DEBUG=OFF
# export CRAYPE_LINK_TYPE=dynamic
# export CRAY_CPU_TARGET=x86-64
# export MPICH_DIR=/opt/cray/pe/mpich/8.1.31/ofi/amd/6.0
# export HIP_LIB_PATH=/opt/rocm-6.2.4/lib
#
# # Ensemble simulations from template
# export LD_LIBRARY_PATH=/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/compiled_software/Stormwater-Management-Model/build/bin:$LD_LIBRARY_PATH
#
# OMP_NUM_THREADS=1 srun /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/build/triton /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/TRITONSWMM.cfg > /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/tritonswmm_sim_logfiles/2026-01-14T084049-0500.log 2>&1 &
# OMP_NUM_THREADS=1 srun /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/build/triton /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/TRITONSWMM.cfg > /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/tritonswmm_sim_logfiles/2026-01-14T084049-0500.log 2>&1 &
#
# wait

# %%
launch_functions = self._create_launchable_sims(pickup_where_leftoff=False, verbose = True)
self.run_simulations_concurrently_on_desktop(launch_functions, use_gpu = False, total_gpus_available=0, verbose=True)
# Out:
# running TRITON-SWMM simulatoin for event 0-event_id.0
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/tritonswmm_sim_logfiles/2026-01-13T170838-0500.log
# running TRITON-SWMM simulatoin for event 1-event_id.1
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/tritonswmm_sim_logfiles/2026-01-13T170838-0500.log
# Running up to 4 sims concurrently
# Simulation 1 finished: simulation completed
# Simulation 0 finished: simulation completed
# ['simulation completed', 'simulation completed']

# %%
self.process_all_sim_timeseries(which = "both", clear_raw_outputs=True, overwrite_if_exist=True, verbose = True)
# Out:
# Time to load bin triton outputs (min) 0.04
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/TRITON_tseries.zarr
# ##################################
# Found problem. Orifice conduits do not return max velocity or max over full flow. Filling with empty string
# Normal row vs. problem row:
#   0                    CONDUIT     0.000     0  00:01      0.00    0.00    0.01
#
#   756                  ORIFICE     0.000     0  00:00                      0.00
#
# Properly parsed values:
# ['756', 'ORIFICE', '0.000', '0', '00:00', '', '', '0.00\n']
# Converted variable to datatype = type, <class 'str'>
# Converted variable to datatype = OutfallType, <class 'str'>
# Converted variable to datatype = StageOrTimeseries, <class 'str'>
# Converted variable to datatype = StorageCurve, <class 'str'>
# Converted variable to datatype = Coefficient, <class 'str'>
# Converted variable to datatype = type, <class 'str'>
# Converted variable to datatype = InletNode, <class 'str'>
# Converted variable to datatype = OutletNode, <class 'str'>
# Converted variable to datatype = OrificeType, <class 'str'>
# Converted variable to datatype = FlapGate, <class 'str'>
# Converted variable to datatype = Shape, <class 'str'>
# /home/***REMOVED***/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/process_simulation.py:493: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'node_id' ('node_id',) The recommendation is to set join explicitly for this case.
#   ds_nodes = xr.merge(
# /home/***REMOVED***/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/process_simulation.py:500: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'link_id' ('link_id',) The recommendation is to set join explicitly for this case.
#   ds_links = xr.merge(
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=4, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=10, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=3, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=7, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=8, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/SWMM_node_tseries.zarr
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=13, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=10, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=4, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=3, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=7, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/0-event_id.0/SWMM_link_tseries.zarr
# Time to load bin triton outputs (min) 0.04
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/TRITON_tseries.zarr
# ##################################
# Found problem. Orifice conduits do not return max velocity or max over full flow. Filling with empty string
# Normal row vs. problem row:
#   0                    CONDUIT     0.000     0  00:01      0.00    0.00    0.01
#
#   756                  ORIFICE     0.000     0  00:00                      0.00
#
# Properly parsed values:
# ['756', 'ORIFICE', '0.000', '0', '00:00', '', '', '0.00\n']
# Converted variable to datatype = type, <class 'str'>
# Converted variable to datatype = OutfallType, <class 'str'>
# Converted variable to datatype = StageOrTimeseries, <class 'str'>
# Converted variable to datatype = StorageCurve, <class 'str'>
# Converted variable to datatype = Coefficient, <class 'str'>
# Converted variable to datatype = type, <class 'str'>
# Converted variable to datatype = InletNode, <class 'str'>
# Converted variable to datatype = OutletNode, <class 'str'>
# Converted variable to datatype = OrificeType, <class 'str'>
# Converted variable to datatype = FlapGate, <class 'str'>
# Converted variable to datatype = Shape, <class 'str'>
# /home/***REMOVED***/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/process_simulation.py:493: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'node_id' ('node_id',) The recommendation is to set join explicitly for this case.
#   ds_nodes = xr.merge(
# /home/***REMOVED***/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/process_simulation.py:500: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'link_id' ('link_id',) The recommendation is to set join explicitly for this case.
#   ds_links = xr.merge(
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=4, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=10, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=3, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=7, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=8, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/SWMM_node_tseries.zarr
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=13, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=10, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=4, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=3, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# /home/***REMOVED***/miniconda3/envs/triton_swmm_toolkit/lib/python3.11/site-packages/zarr/core/dtype/npy/string.py:249: UnstableSpecificationWarning: The data type (FixedLengthUTF32(length=7, endianness='little')) does not have a Zarr V3 specification. That means that the representation of arrays saved with this data type may change without warning in a future version of Zarr Python. Arrays stored with this data type may be unreadable by other Zarr libraries. Use this data type at your own risk! Check https://github.com/zarr-developers/zarr-extensions/tree/main/data-types for the status of data type specifications for Zarr V3.
#   v3_unstable_dtype_warning(self)
# finished writing /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/sims/1-event_id.1/SWMM_link_tseries.zarr

# %%
self.log.all_sims_run.get()
# Out:
# True
