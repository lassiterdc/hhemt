# %%
# %load_ext autoreload
# %autoreload 2
import TRITON_SWMM_toolkit.examples as examples
import TRITON_SWMM_toolkit.analysis as analysis
from TRITON_SWMM_toolkit.process_simulation import TRITONSWMM_sim_post_processing
import TRITON_SWMM_toolkit.process_simulation as ps
import TRITON_SWMM_toolkit.processing_analysis as pe
from TRITON_SWMM_toolkit.process_simulation import *
import TRITON_SWMM_toolkit.plot_utils as plot_utils
import TRITON_SWMM_toolkit.utils as utils 
import TRITON_SWMM_toolkit.run_simulation as run
import TRITON_SWMM_toolkit.sensitivity_analysis as snst
from TRITON_SWMM_toolkit.config import analysis_config

from importlib import reload
reload(examples)
reload(analysis)
reload(ps)
reload(pe)
reload(plot_utils)
reload(utils)
reload(snst)
# norfolk_singlesim = examples.GetTS_TestCases.retreive_norfolk_single_sim_test_case(download_if_exists=False)
# norfolk_multisim = examples.GetTS_TestCases.retreive_norfolk_multi_sim_test_case()
nrflk_cpu_sensitivity = examples.GetTS_TestCases.retreive_norfolk_cpu_config_sensitivity_case(start_from_scratch=False)
self = snst.TRITONSWMM_sensitivity_analysis(nrflk_cpu_sensitivity.system.analysis)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
self.master_analysis.compile_TRITON_SWMM(recompile_if_already_done_successfully=False)

# %%
self.prepare_scenarios_in_each_subanalysis()
# Out:
# ... SWMM Version 5.2.4
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... Run Complete
# ... SWMM Version 5.2.4
# ... Run Complete
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... SWMM Version 5.2.4
# ... Run Complete
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete
# ... SWMM Version 5.2.4
# ... Run Complete
#  o  Retrieving project data
#  o  Simulating day: 0     hour: Simulation complete

# %%
self.master_analysis.cfg_analysis.weather_timeseries
# Out:
# PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/weather_tseries.nc')

# %%
self.df_setup
# Out:
#   run_mode  n_mpi_procs  n_omp_threads
# 0      mpi            2              1
# 1   openmp            1              2
# 2   hybrid            2              2
# 3   serial            1              1

# %%
self.master_analysis.log.print()
# Out:
# {
#     "logfile": "/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/log.json",
#     "all_scenarios_created": true,
#     "TRITONSWMM_compiled_successfully": true,
#     "all_sims_run": true,
#     "all_TRITON_timeseries_processed": true,
#     "all_SWMM_timeseries_processed": true,
#     "all_raw_TRITON_outputs_cleared": true,
#     "all_raw_SWMM_outputs_cleared": true,
#     "TRITON_analysis_summary_created": true,
#     "SWMM_node_analysis_summary_created": true,
#     "SWMM_link_analysis_summary_created": true,
#     "processing_log": {
#         "outputs": {
#             "TRITON.zarr": {
#                 "filepath": "/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/cpu_config_sensitivity/TRITON.zarr",
#                 "size_MiB": 1.09,
#                 "time_elapsed_s": 6.07,
#                 "success": true,
# ...

# %%
self.run_all_sims(pickup_where_leftoff=True, process_outputs_after_sim_completion=True)

# %%
self.consolidate_TRITON_outputs_for_analysis()
self.consolidate_SWMM_outputs_for_analysis()

# %%
print(self.TRITONSWMM_runtimes.sort_values().reset_index().to_markdown(index = False))
# Out:
# |   n_omp_threads |   n_mpi_procs | run_mode   |   event_iloc |   compute_time_min |
# |----------------:|--------------:|:-----------|-------------:|-------------------:|
# |               2 |             2 | hybrid     |            0 |           0.105723 |
# |               1 |             2 | mpi        |            0 |           0.113332 |
# |               2 |             1 | openmp     |            0 |           0.139592 |
# |               1 |             1 | serial     |            0 |           0.143223 |

# %%
self.master_analysis.TRITON_summary
# Out:
# <xarray.Dataset> Size: 265MB
# Dimensions:                                 (n_omp_threads: 2, n_mpi_procs: 2,
#                                              run_mode: 4, event_iloc: 1,
#                                              x: 551, y: 537)
# Coordinates:
#   * n_omp_threads                           (n_omp_threads) int64 16B 1 2
#   * n_mpi_procs                             (n_mpi_procs) int64 16B 1 2
#   * run_mode                                (run_mode) <U6 96B 'hybrid' ... '...
#   * event_iloc                              (event_iloc) int64 8B 0
#   * x                                       (x) float64 4kB 3.697e+06 ... 3.6...
#   * y                                       (y) float64 4kB 1.06e+06 ... 1.06...
# Data variables:
#     time_of_max_wlevel_min                  (n_omp_threads, n_mpi_procs, run_mode, event_iloc, x, y) float64 38MB dask.array<chunksize=(2, 2, 4, 1, 551, 537), meta=np.ndarray>
# ...

# %%
scen = self.sub_analyses[0].scenarios[0]

event_iloc = 0
df = pd.DataFrame(index = [event_iloc], data = dict(compute_time_min = [scen.sim_compute_time_min]))
df.index.name = "event_iloc"

df.to_xarray()["compute_time_min"]
# Out:
# <xarray.DataArray 'compute_time_min' (event_iloc: 1)> Size: 8B
# array([0.09928865])
# Coordinates:
#   * event_iloc  (event_iloc) int64 8B 0
