# %%
# %load_ext autoreload
# %autoreload 2
import TRITON_SWMM_toolkit.examples as examples
import TRITON_SWMM_toolkit.experiment as exp
from TRITON_SWMM_toolkit.post_processing import TRITONSWMM_post_processing
import TRITON_SWMM_toolkit.post_processing as pp
from TRITON_SWMM_toolkit.post_processing import *
from importlib import reload
reload(examples)
reload(exp)
reload(pp)
norfolk_irene = examples.TRITON_SWMM_testcases.retreive_norfolk_single_sim_test_case(download_if_exists=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
norfolk_irene

# %%
examples.TRITON_SWMM_examples.load_norfolk_single_sim_experiment()
# Out:
# PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/system/config_experiment_single_sim.yaml')

# %% [markdown]
# Events to include in multi sim experiment:
# - 2011-08-28
# - 2015-07-11
# - 2015-10-04
# - 2016-09-03
# - 2016-09-21
# - 2017-08-29

# %%
csv_obs = Path(examples.get_norfolk_data_and_package_directory_mapping_dict()["DATA_DIR"]) / "obs_event_summaries_from_yrs_with_complete_coverage.csv"
assert csv_obs.exists()

# %%
import TRITON_SWMM_toolkit.config as cfg

exp = cfg.load_experiment_config(single_sim_exp_yaml)

experiment_name = "test"
experiment_description = ""

exp.experiment_id = experiment_name
exp.experiment_description = experiment_description
f_weather_indices = (
    exp.weather_timeseries.parent
    / experiment_name
    / "weather_indices.csv"
)
exp.weather_events_to_simulate = f_weather_indices
cfg_exp = cfg.experiment_config.model_validate(exp)

# %%
cfg_exp.model_dump()
# Out:
# {'experiment_id': 'test',
#  'weather_event_indices': ['year', 'event_type', 'event_id'],
#  'weather_timeseries': PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/obs_event_tseries_from_yrs_with_complete_coverage.nc'),
#  'weather_time_series_timestep_dimension_name': 'timestep',
#  'rainfall_units': 'mm/hr',
#  'toggle_benchmarking_experiment': False,
#  'toggle_storm_tide_boundary': True,
#  'storm_tide_boundary_line_gis': PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/shp_boundary_condition/variable_bc.shp'),
#  'storm_tide_units': 'm',
#  'weather_event_summary_csv': PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/obs_event_summaries_from_yrs_with_complete_coverage.csv'),
#  'weather_time_series_storm_tide_datavar': 'waterlevel_m',
#  'benchmarking_experiment': None,
# ...
