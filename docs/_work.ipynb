# %%
# %load_ext autoreload
# %autoreload 2
import TRITON_SWMM_toolkit.examples as examples
import TRITON_SWMM_toolkit.analysis as analysis
from TRITON_SWMM_toolkit.process_simulation import TRITONSWMM_sim_post_processing
import TRITON_SWMM_toolkit.process_simulation as ps
import TRITON_SWMM_toolkit.processing_analysis as pe
from TRITON_SWMM_toolkit.process_simulation import *
import TRITON_SWMM_toolkit.plot_utils as plot_utils
import TRITON_SWMM_toolkit.utils as utils 
import TRITON_SWMM_toolkit.run_simulation as run

from importlib import reload
reload(examples)
reload(analysis)
reload(ps)
reload(pe)
reload(plot_utils)
reload(utils)

norfolk_singlesim = examples.TRITON_SWMM_testcases.retreive_norfolk_single_sim_test_case(download_if_exists=False)
norfolk_multisim = examples.TRITON_SWMM_testcases.retreive_norfolk_multi_sim_test_case()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 22
#      19 reload(utils)
#      21 norfolk_singlesim = examples.TRITON_SWMM_testcases.retreive_norfolk_single_sim_test_case(download_if_exists=False)
# ---> 22 norfolk_multisim = examples.TRITON_SWMM_testcases.retreive_norfolk_multi_sim_test_case()
#
# File ~/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/examples.py:310, in TRITON_SWMM_testcases.retreive_norfolk_multi_sim_test_case(cls, start_from_scratch, download_if_exists)
#     304 @classmethod
#     305 def retreive_norfolk_multi_sim_test_case(
#     306     cls, start_from_scratch: bool = False, download_if_exists: bool = False
#     307 ):
#     308     analysis_name = "multi_sim"
# --> 310     return cls._retrieve_norfolk_case(
#     311         analysis_name=analysis_name,
#     312         start_from_scratch=start_from_scratch,
# ...

# %%
reload(run)
self = norfolk_singlesim.system.analysis._retreive_sim_run_object(0)
exe = self._scenario.scen_paths.sim_tritonswmm_executable
cfg = self._scenario.scen_paths.triton_swmm_cfg
sim_id_str = self._scenario._retrieve_sim_id_str()
tritonswmm_logfile_dir = self._scenario.scen_paths.tritonswmm_logfile_dir
compiled_software_dir = self._analysis.analysis_paths.compiled_software_directory
sim_datetime = current_datetime_string()

# %%
self.run_sim(mode = "single_core", pickup_where_leftoff = False)
# Out:
# running TRITON-SWMM simulatoin for event 0-event_id.0
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/2026-01-09T215328-0500.log

# %%
run_mode = "openmp"

extra_env = {
    "OMP_DISPLAY_ENV": "TRUE"
}

tritonswmm_logfile = (
    tritonswmm_logfile_dir
    / f"{run_mode}.log"
)  # individual sim log

run.run_hydromodel(
    exe,
    cfg,
    logfile=tritonswmm_logfile,
    compiled_software_dir=compiled_software_dir,
    run_mode=run_mode,
    n_omp_threads=4,  # use all logical CPUs
    extra_env =extra_env
)
print("bash command to view progress:")
print(f"tail -f {tritonswmm_logfile}")
# Out:
# Running mode: openmp
# Command: /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/build/triton /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/TRITONSWMM.cfg
# OMP_NUM_THREADS: 4
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/openmp.log

# %%
run_mode = "mpi"

tritonswmm_logfile = (
    tritonswmm_logfile_dir
    / f"{run_mode}.log"
)  # individual sim log

run.run_hydromodel(
    exe,
    cfg,
    logfile=tritonswmm_logfile,
    compiled_software_dir=compiled_software_dir,
    run_mode=run_mode,
    # n_omp_threads=4,  # use all logical CPUs
    n_mpi_procs=2,  # 2 MPI ranks
)
print("bash command to view progress:")
print(f"tail -f {tritonswmm_logfile}")
# Out:
# Running mode: mpi
# Command: mpirun -np 2 /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/build/triton /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/TRITONSWMM.cfg
# OMP_NUM_THREADS: 1
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/mpi.log

# %%
run_mode = "hybrid"

tritonswmm_logfile = (
    tritonswmm_logfile_dir
    / f"{run_mode}.log"
)  # individual sim log

run.run_hydromodel(
    exe,
    cfg,
    logfile=tritonswmm_logfile,
    compiled_software_dir=compiled_software_dir,
    run_mode=run_mode,
    n_mpi_procs=2,      # 2 MPI ranks
    n_omp_threads=2,    # 2 threads per rank → total 4 threads
)
print("bash command to view progress:")
print(f"tail -f {tritonswmm_logfile}")
# Out:
# Running mode: hybrid
# Command: mpirun -np 2 /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/build/triton /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/TRITONSWMM.cfg
# OMP_NUM_THREADS: 2
# bash command to view progress:
# tail -f /home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/tests/single_sim/sims/0-event_id.0/tritonswmm_sim_logfiles/hybrid.log
