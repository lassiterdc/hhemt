# %%
import TRITON_SWMM_toolkit.examples as examples
import TRITON_SWMM_toolkit.analysis as exp
from TRITON_SWMM_toolkit.post_processing import TRITONSWMM_sim_post_processing
import TRITON_SWMM_toolkit.post_processing as pp
from TRITON_SWMM_toolkit.post_processing import *
from importlib import reload
reload(examples)
reload(exp)
reload(pp)
norfolk_irene = examples.retrieve_norfolk_singlesim_testcase(download_if_exists=False)
run = norfolk_irene.system.analysis._retreive_sim_run_object(0)

# working on run methods
self = TRITONSWMM_sim_post_processing(run)
self._run.latest_sim_status()

self.export_TRITON_outputs(verbose = True)
# Out:
# TRITON_tseries.zarr already written. Not overwriting.

# %%
self.export_SWMM_outputs(verbose = True)
# Out:
# SWMM_node_tseries.zarr and SWMM_link_tseries.zarr already written. Not overwriting.

# %%
import TRITON_SWMM_toolkit.post_processing as pst
from importlib import reload
reload(pst)
# Out:
# <module 'TRITON_SWMM_toolkit.post_processing' from '/home/***REMOVED***/dev/TRITON-SWMM_toolkit/src/TRITON_SWMM_toolkit/post_processing.py'>
