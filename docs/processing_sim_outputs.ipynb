# %%
from TRITON_SWMM_toolkit.examples import load_norfolk_single_sim_experiment
from TRITON_SWMM_toolkit.prepare_an_experiment import compile_TRITON_SWMM
cfg_exp_1sim = load_norfolk_single_sim_experiment()
experiment_id = cfg_exp_1sim.experiment_id

cfg_exp_1sim
# Out:
# experiment_config(experiment_id='single_sim', toggle_benchmarking_experiment=False, benchmarking_experiment=None, weather_events_to_simulate=PosixPath('/home/***REMOVED***/.local/share/TRITON_SWMM_toolkit/examples/norfolk_coastal_flooding/data/contents/hurricane_irene_event_index.csv'), experiment_description='Single Simulation of Hurricane Irene 8-27-2011', TRITON_SWMM_make_command=PosixPath('hpc_swmm_omp'))
